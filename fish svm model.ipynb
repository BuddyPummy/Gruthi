# %%
pip install pandas matplotlib seaborn sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
Fish = pd.read_csv("D:/aiml/Fish.csv")
Fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream    23.2     25.4      NaN    11.52   4.0200     NaN
# 1     Bream    24.0     26.3     31.2    12.48   4.3056     NaN
# 2     Bream   340.0     23.9     26.5    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0    34.00   0.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0    16.20   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
Fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  158 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    153 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
Fish.isnull()
# Out:
#      Species  Weight  Length1  Length2  Length3  Height  Width
# 0      False   False    False     True    False   False   True
# 1      False   False    False    False    False   False   True
# 2      False   False    False    False    False   False  False
# 3      False   False    False    False    False   False  False
# 4      False   False    False    False    False   False  False
# ..       ...     ...      ...      ...      ...     ...    ...
# 154    False   False    False    False    False   False  False
# 155    False   False    False    False    False   False  False
# 156    False   False    False    False    False   False  False
# 157    False   False    False    False    False   False  False
# 158    False   False    False    False    False   False  False
#
# [159 rows x 7 columns]

# %%
Fish.dropna()
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0   0.4440  5.1340
# 5     Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6     Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [153 rows x 7 columns]

# %%
Fish.fillna(1)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream    23.2     25.4      1.0    11.52   4.0200  1.0000
# 1     Bream    24.0     26.3     31.2    12.48   4.3056  1.0000
# 2     Bream   340.0     23.9     26.5    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0    34.00   0.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0    16.20   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
Fish['Width'].fillna(Fish['Width'].mean(),inplace=True)
Fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream    23.2     25.4      NaN    11.52   4.0200  4.4072
# 1     Bream    24.0     26.3     31.2    12.48   4.3056  4.4072
# 2     Bream   340.0     23.9     26.5    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0    34.00   0.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0    16.20   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
Fish.isnull()
# Out:
#      Species  Weight  Length1  Length2  Length3  Height  Width
# 0      False   False    False     True    False   False  False
# 1      False   False    False    False    False   False  False
# 2      False   False    False    False    False   False  False
# 3      False   False    False    False    False   False  False
# 4      False   False    False    False    False   False  False
# ..       ...     ...      ...      ...      ...     ...    ...
# 154    False   False    False    False    False   False  False
# 155    False   False    False    False    False   False  False
# 156    False   False    False    False    False   False  False
# 157    False   False    False    False    False   False  False
# 158    False   False    False    False    False   False  False
#
# [159 rows x 7 columns]

# %%
Fish.dropna()
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 1     Bream    24.0     26.3     31.2    12.48   4.3056  4.4072
# 2     Bream   340.0     23.9     26.5    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0    34.00   0.4440  5.1340
# 5     Bream   450.0     26.8     29.7    34.70  13.6024  4.9274
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0    16.20   2.9322  1.8792
#
# [158 rows x 7 columns]

# %%
Fish.fillna(1)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream    23.2     25.4      1.0    11.52   4.0200  4.4072
# 1     Bream    24.0     26.3     31.2    12.48   4.3056  4.4072
# 2     Bream   340.0     23.9     26.5    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0    34.00   0.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0    16.20   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
Fish['Length2'].fillna(Fish['Length2'].mean(),inplace=True)
Fish
# Out:
#     Species  Weight  Length1    Length2  Length3   Height   Width
# 0     Bream    23.2     25.4  28.529747    11.52   4.0200  4.4072
# 1     Bream    24.0     26.3  31.200000    12.48   4.3056  4.4072
# 2     Bream   340.0     23.9  26.500000    31.10  12.3778  4.6961
# 3     Bream   363.0     26.3  29.000000    33.50  12.7300  4.4555
# 4     Bream   430.0     26.5  29.000000    34.00   0.4440  5.1340
# ..      ...     ...      ...        ...      ...      ...     ...
# 154   Smelt    12.2     11.5  12.200000    13.40   2.0904  1.3936
# 155   Smelt    13.4     11.7  12.400000    13.50   2.4300  1.2690
# 156   Smelt    12.2     12.1  13.000000    13.80   2.2770  1.2558
# 157   Smelt    19.7     13.2  14.300000    15.20   2.8728  2.0672
# 158   Smelt    19.9     13.8  15.000000    16.20   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
X = Fish.drop(['Species'], axis = 'columns')
y = Fish.Species
print(X,y)
# Out:
#      Weight  Length1    Length2  Length3   Height   Width
# 0      23.2     25.4  28.529747    11.52   4.0200  4.4072
# 1      24.0     26.3  31.200000    12.48   4.3056  4.4072
# 2     340.0     23.9  26.500000    31.10  12.3778  4.6961
# 3     363.0     26.3  29.000000    33.50  12.7300  4.4555
# 4     430.0     26.5  29.000000    34.00   0.4440  5.1340
# ..      ...      ...        ...      ...      ...     ...
# 154    12.2     11.5  12.200000    13.40   2.0904  1.3936
# 155    13.4     11.7  12.400000    13.50   2.4300  1.2690
# 156    12.2     12.1  13.000000    13.80   2.2770  1.2558
# 157    19.7     13.2  14.300000    15.20   2.8728  2.0672
# 158    19.9     13.8  15.000000    16.20   2.9322  1.8792
#
# [159 rows x 6 columns] 0      Bream
# 1      Bream
# 2      Bream
# 3      Bream
# 4      Bream
#        ...
# 154    Smelt
# 155    Smelt
# 156    Smelt
# 157    Smelt
# 158    Smelt
# Name: Species, Length: 159, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)
X_train, X_test, y_train, y_test
# Out:
# (     Weight  Length1  Length2  Length3   Height   Width
#  76     70.0     15.7     17.4     18.5   4.5880  2.9415
#  78     78.0     16.8     18.7     19.4   5.1992  3.1234
#  64    120.0     17.5     19.0     21.3   8.3922  2.9181
#  88    130.0     20.0     22.0     23.5   6.1100  3.5250
#  28    850.0     32.8     36.0     41.6  16.8896  6.1984
#  ..      ...      ...      ...      ...      ...     ...
#  13    340.0     29.5     32.0     37.3  13.9129  5.0728
#  104   265.0     25.4     27.5     28.9   7.0516  4.3350
#  43    150.0     20.4     22.0     24.7   5.8045  3.7544
#  124  1000.0     39.8     43.0     45.2  11.9328  7.2772
#  40      0.0     19.0     20.5     22.8   6.4752  3.3516
#
#  [127 rows x 6 columns],
#       Weight  Length1  Length2  Length3   Height   Width
#  82    110.0     19.0     21.0     22.5   5.6925  3.5550
#  118   820.0     36.6     39.0     41.3  12.4313  7.3514
#  127  1000.0     41.1     44.0     46.6  12.4888  7.5958
# ...

# %%
svm_model_linear = SVC(kernel = 'linear', C = 1)
svm_model_linear.fit(X_train, y_train)
svm_model_linear
# Out:
# SVC(C=1, kernel='linear')

# %%
svm_pred = svm_model_linear.predict(X_test)
svm_pred
# Out:
# array(['Roach', 'Perch', 'Perch', 'Bream', 'Roach', 'Parkki', 'Perch',
#        'Smelt', 'Roach', 'Perch', 'Perch', 'Bream', 'Parkki', 'Perch',
#        'Perch', 'Perch', 'Perch', 'Bream', 'Perch', 'Parkki', 'Bream',
#        'Roach', 'Roach', 'Roach', 'Parkki', 'Perch', 'Smelt', 'Bream',
#        'Perch', 'Bream', 'Perch', 'Perch'], dtype=object)

# %%
accuracy = svm_model_linear.score(X_test, y_test)
accuracy
# Out:
# 0.9375
