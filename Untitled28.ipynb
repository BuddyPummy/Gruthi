# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data =pd.read_csv('D:/aiml/healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data = np.asarray(data.iloc[0:1,1:])
plt.subplot(1,2,1)
plt.imshow(data,cmap = plt.cm.gray_r)
plt.title("First digit in train data")
plt.subplot(1,2,2)
plt.imshow(data_digit1,cmap = plt.cm.gray_r)
plt.title("First digit in test data ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 data = np.asarray(data.iloc[0:1,1:])
#       2 plt.subplot(1,2,1)
# ----> 3 plt.imshow(data,cmap = plt.cm.gray_r)
#       4 plt.title("First digit in train data")
#       5 plt.subplot(1,2,2)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...

# %%
X_train = data.iloc[:,1:]
Y_train = data.iloc[:,0:1]
print(X_train,Y_train )
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
from sklearn.neural_network import MLPClassifier
nn_model = MLPClassifier(hidden_layer_sizes=(50))
nn_model.fit(X_train,data.iloc[:,0])
predictions = nn_model.predict(X_train)
print(nn_model.predict(data.iloc[0:1,]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 from sklearn.neural_network import MLPClassifier
#       2 nn_model = MLPClassifier(hidden_layer_sizes=(50))
# ----> 3 nn_model.fit(X_train,data.iloc[:,0])
#       4 predictions = nn_model.predict(X_train)
#       5 print(nn_model.predict(data.iloc[0:1,]))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(Y_train,predictions),
             index=range(0,10),columns=range(0,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 pd.DataFrame(confusion_matrix(Y_train,predictions),
#       3              index=range(0,10),columns=range(0,10))
#
# NameError: name 'predictions' is not defined
